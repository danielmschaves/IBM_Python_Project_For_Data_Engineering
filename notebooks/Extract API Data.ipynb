# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # Peer Review Assignment - Data Engineer - Extract API Data

# %% [markdown]
# Estimated time needed: **20** minutes

# %% [markdown]
# ## Objectives
#
# In this part you will:
#
# *   Collect exchange rate data using an API
# *   Store the data as a CSV

# %% [markdown]
# For this lab, we are going to be using Python and several Python libraries. Some of these libraries might be installed in your lab environment or in SN Labs. Others may need to be installed by you. The cells below will install these libraries when executed.

# %%
# !mamba install pandas==1.3.3 -y
# !mamba install requests==2.26.0 -y
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.27.0) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['pandas==1.3.3']
#
# [+] 0.0s
# opt/ibm/custom-channels/meta-wscloud/linux-64 ━━━━━━━━━━━╸━━━━━━━━   0.0 B  0.0s
# opt/ibm/custom-channels/meta-wscloud/noarch   ━━━━━━━╸━━━━━━━━━━━━   0.0 B  0.0sopt/ibm/custom-channels/meta-wscloud/linux-64       0.0s
# opt/ibm/custom-channels/meta-wscloud/noarch         0.0s
# opt/ibm/custom-channels/placebo-20220915-noarch/..  ??.?MB @  ??.?MB/s 0 failed  0.0s
# opt/ibm/custom-channels/placebo-20220915-noarch/..   3.6kB @  81.5MB/s  0.0s
# [+] 0.1s
# pkgs/main/linux-64 ━━╸━━━━━━━━━━━━━━━╸━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/main/noarch   ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s[+] 0.2s
# pkgs/main/linux-64 ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# pkgs/main/noarch   ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s[+] 0.3s
# pkgs/main/linux-64 ━━━━━╸━━━━━━━━━━━━━━━╸━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3s
# pkgs/main/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3spkgs/main/noarch                                              No change
# [+] 0.4s
# pkgs/main/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━╸━   6.0kB /  ??.?MB @  16.3kB/s  0.4s[+] 0.5s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━ 561.2kB /  ??.?MB @   1.2MB/s  0.5s[+] 0.6s
# pkgs/main/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━━━   1.2MB /  ??.?MB @   2.0MB/s  0.6s[+] 0.7s
# pkgs/main/linux-64 ━━━━━━━━━━━━━━╸━━━━━━━━━━   1.8MB /  ??.?MB @   2.6MB/s  0.7s[+] 0.8s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   2.4MB /  ??.?MB @   3.0MB/s  0.8s[+] 0.9s
# pkgs/main/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━━━   2.9MB /  ??.?MB @   3.3MB/s  0.9s[+] 1.0s
# pkgs/main/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━━━   3.5MB /  ??.?MB @   3.6MB/s  1.0s[+] 1.1s
# pkgs/main/linux-64 ╸━━━━━━━━━━━━━━━╸━━━━━━━━   4.1MB /  ??.?MB @   3.8MB/s  1.1s[+] 1.2s
# pkgs/main/linux-64 ━━╸━━━━━━━━━━━━━━━╸━━━━━━   4.7MB /  ??.?MB @   4.0MB/s  1.2s[+] 1.3s
# pkgs/main/linux-64 ━━━━━━━━━━━━━━━━━━━━━━━━   5.0MB @   4.0MB/s Finalizing  1.3spkgs/main/linux-64                                 @   4.0MB/s  1.3s
#
# Pinned packages:
#   - python 3.9.*
#   - python 3.9.*
#   - widgetsnbextension 3.5.1.*
#
#
# Transaction
#
#   Prefix: /opt/conda/envs/Python-3.9
#
#   Updating specs:
#
#    - pandas==1.3.3
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package                 Version  Build           Channel                                          Size
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   + ibm-wsrt-py39t1-keep    0.0.0  0               /opt/ibm/custom-channels/meta-wscloud/noarch      2kB
#
#   Downgrade:
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   - ibm-wsrt-py39t1-main    0.0.0  0               opt/ibm/custom-channels/meta-wscloud
#   + ibm-wsrt-py39t1-main   custom  0               /opt/ibm/custom-channels/meta-wscloud/noarch      2kB
#   - pandas                  1.3.4  py39h8c16a72_0  pkgs/main
#   + pandas                  1.3.3  py39h8c16a72_0  pkgs/main/linux-64                               10MB
#
#   Summary:
#
#   Install: 1 packages
#   Downgrade: 2 packages
#
#   Total download: 10MB
#
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# [+] 0.0s
# Downloading  (2) ━━━━━━━━━━━━━━━━━━━━━╸━   0.0 B ibm-wsrt-py39t1-keep       0.0s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0sibm-wsrt-py39t1-keep                                 2.3kB @  23.3MB/s  0.0s
# ibm-wsrt-py39t1-main                                 1.9kB @  38.2MB/s  0.0s
# [+] 0.1s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   4.2kB pandas                     0.1s
# Extracting   (2) ━━━━━━━━━━━━╸━━━━━━━━━━       0 ibm-wsrt-py39t1-keep       0.0s[+] 0.2s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   4.2kB pandas                     0.2s
# Extracting   (2) ━━━━━━━━━━━━━╸━━━━━━━━━       0 ibm-wsrt-py39t1-keep       0.1s[+] 0.3s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   4.7kB pandas                     0.3s
# Extracting   (2) ━━━━━━━━━━━━━━╸━━━━━━━━       0 ibm-wsrt-py39t1-keep       0.2s[+] 0.4s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━ 377.9kB pandas                     0.4s
# Extracting   (2) ━━━━━━━━━━━━━━━╸━━━━━━━       0 ibm-wsrt-py39t1-keep       0.3s[+] 0.5s
# Downloading  (1) ╸━━━━━━━━━━━━━━━━━━━━━━ 705.5kB pandas                     0.5s
# Extracting   (2) ╸━━━━━━━━━━━━━━━╸━━━━━━       0 ibm-wsrt-py39t1-main       0.4s[+] 0.6s
# Downloading  (1) ━╸━━━━━━━━━━━━━━━━━━━━━   1.1MB pandas                     0.6s
# Extracting   (2) ━━╸━━━━━━━━━━━━━━━╸━━━━       0 ibm-wsrt-py39t1-main       0.5s[+] 0.7s
# Downloading  (1) ━━━╸━━━━━━━━━━━━━━━━━━━   1.9MB pandas                     0.7s
# Extracting   (2) ━━━╸━━━━━━━━━━━━━━━╸━━━       0 ibm-wsrt-py39t1-main       0.6s[+] 0.8s
# Downloading  (1) ━━━━━╸━━━━━━━━━━━━━━━━━   2.8MB pandas                     0.8s
# Extracting   (2) ━━━━╸━━━━━━━━━━━━━━━╸━━       0 ibm-wsrt-py39t1-main       0.7s[+] 0.9s
# Downloading  (1) ━━━━━━╸━━━━━━━━━━━━━━━━   3.5MB pandas                     0.9s
# Extracting   (2) ━━━━━╸━━━━━━━━━━━━━━━╸━       0 ibm-wsrt-py39t1-keep       0.8s[+] 1.0s
# Downloading  (1) ━━━━━━━━━╸━━━━━━━━━━━━━   4.5MB pandas                     1.0s
# Extracting   (1) ━━━━━━╸━━━━━━━━╸━━━━━━━       1 ibm-wsrt-py39t1-main       0.9s[+] 1.1s
# Downloading  (1) ━━━━━━━━━━━━╸━━━━━━━━━━   5.9MB pandas                     1.1s
# Extracting   (1) ━━━━━━╸━━━━━━━━╸━━━━━━━       1 ibm-wsrt-py39t1-main       1.0s[+] 1.2s
# Downloading  (1) ━━━━━━━━━━━━━━╸━━━━━━━━   6.9MB pandas                     1.2s
# Extracting       ━━━━━━━━━━━━━━╸━━━━━━━━       2                            1.1s[+] 1.3s
# Downloading  (1) ━━━━━━━━━━━━━━━━╸━━━━━━   7.8MB pandas                     1.3s
# Extracting       ━━━━━━━━━━━━━━╸━━━━━━━━       2                            1.1s[+] 1.4s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━╸━━━   8.8MB pandas                     1.4s
# Extracting       ━━━━━━━━━━━━━━╸━━━━━━━━       2                            1.1spandas                                              10.0MB @   7.0MB/s  1.4s
# [+] 1.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            1.5s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                     1.1s[+] 1.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            1.5s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                     1.2s[+] 1.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            1.5s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                     1.3s[+] 1.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            1.5s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                     1.4s[+] 1.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            1.5s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                     1.5s[+] 2.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            1.5s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                     1.6s[+] 2.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            1.5s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                     1.7s[+] 2.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            1.5s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                     1.8s[+] 2.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            1.5s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                     1.9s[+] 2.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            1.5s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                     2.0s[+] 2.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            1.5s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                     2.1s[+] 2.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            1.5s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       2 pandas                     2.2s[+] 2.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  10.0MB                            1.5s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       3                            2.3sPreparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.27.0) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['requests==2.26.0']
#
# pkgs/main/linux-64                                          Using cache
# pkgs/main/noarch                                            Using cache
# [+] 0.0s
# opt/ibm/custom-channels/meta-wscloud/linux-64 ━━━━━━━━╸━━━━━━━━━━━   0.0 B  0.0s
# opt/ibm/custom-channels/meta-wscloud/noarch   ━━━━━━━━━━╸━━━━━━━━━   0.0 B  0.0sopt/ibm/custom-channels/meta-wscloud/linux-64       0.0s
# opt/ibm/custom-channels/meta-wscloud/noarch         0.0s
# opt/ibm/custom-channels/placebo-20220915-noarch/..  ??.?MB @  ??.?MB/s 0 failed  0.0s
# opt/ibm/custom-channels/placebo-20220915-noarch/..   3.6kB @  73.2MB/s  0.0s
#
# Pinned packages:
#   - python 3.9.*
#   - python 3.9.*
#   - widgetsnbextension 3.5.1.*
#
#
# Transaction
#
#   Prefix: /opt/conda/envs/Python-3.9
#
#   All requested packages already installed

# %% [markdown]
# ## Imports
#
# Import any additional libraries you may need here.

# %%
import requests
import pandas as pd

# %% [markdown]
# ## Extract Data Using an API

# %% [markdown]
# Using ExchangeRate-API we will extract currency exchange rate data. Use the below steps to get the access key and to get the data.
#
# 1.  Open the url : [https://exchangeratesapi.io/](https://exchangeratesapi.io/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01) and click on **Get Free API Key**.
# 2.  Subscribe for Free plan and Sign-in with the Google Account.
# 3.  Once the account is created you will be redirected to [https://apilayer.com](https://apilayer.com/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01) website.
# 4.  Now, click on the **user icon** and click **Account** as shown below:
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0221EN-SkillsNetwork/labs/module%206/Final%20Assignment/Images/account.png"/>
#
# 3.  Scroll down and you will get the API Key section. Copy the API key and use in the url in Question 1.

# %% [markdown]
# ### Call the API
#
# <b> Question 1</b> Using the `requests` library call the endpoint given above and save the text, remember the first few characters of the output:

# %%
# Write your code here
import requests
url = "https://api.apilayer.com/exchangerates_data/latest?base=EUR&apikey=u4PBs1GvMURvneGDRY70uNwrv9YVWFX1" #Make sure to change ******* to your API key.
json_data = requests.get(url).text

# %% [markdown]
# ### Save as DataFrame
#
# <b> Question 2</b>  Using the data gathered turn it into a `pandas` dataframe. The dataframe should have the Currency as the index and `Rate` as their columns. Make sure to drop unnecessary columns.

# %%
# Turn the data into a dataframe
data = pd.read_json(json_data)
data
# Out:
#      success           timestamp base       date        rates
# AED     True 2022-11-18 14:30:06  EUR 2022-11-18     3.804581
# AFN     True 2022-11-18 14:30:06  EUR 2022-11-18    91.777700
# ALL     True 2022-11-18 14:30:06  EUR 2022-11-18   116.954148
# AMD     True 2022-11-18 14:30:06  EUR 2022-11-18   409.333480
# ANG     True 2022-11-18 14:30:06  EUR 2022-11-18     1.865281
# ..       ...                 ...  ...        ...          ...
# YER     True 2022-11-18 14:30:06  EUR 2022-11-18   259.240847
# ZAR     True 2022-11-18 14:30:06  EUR 2022-11-18    17.918460
# ZMK     True 2022-11-18 14:30:06  EUR 2022-11-18  9323.640983
# ZMW     True 2022-11-18 14:30:06  EUR 2022-11-18    17.248640
# ZWL     True 2022-11-18 14:30:06  EUR 2022-11-18   333.534896
#
# [169 rows x 5 columns]

# %%
# Drop unnescessary columns
newdata = data.drop(["success", "timestamp", "base", "date"], axis=1).rename(columns={"rates":"Rate"})
newdata
# Out:
#             Rate
# AED     3.804581
# AFN    91.777700
# ALL   116.954148
# AMD   409.333480
# ANG     1.865281
# ..           ...
# YER   259.240847
# ZAR    17.918460
# ZMK  9323.640983
# ZMW    17.248640
# ZWL   333.534896
#
# [169 rows x 1 columns]

# %% [markdown]
# ### Load the Data
#
# Using the dataframe save it as a CSV names `exchange_rates_1.csv`.

# %%
# Save the Dataframe
with open("exchange_rates_1.csv","w") as openfile:
    openfile.write(newdata.to_csv())

# %% [markdown]
# Your CSV should be in this format with more currencies
#
# |     | Rates      |
# | --- | ---------- |
# | AED | 4.398618   |
# | AFN | 92.917693  |
# | ALL | 123.099093 |
# | AMD | 621.935674 |
# | ANG | 2.149648   |

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy, Joseph Santarcangelo and Azim Hirjani

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                              |
# | ----------------- | ------- | ----------------- | ----------------------------------------------- |
# | 2022-05-06        | 0.3     | Malika            | Updated instructions to get the API and the url |
# | 2021-04-15        | 0.2     | Malika            | Updated the lab from USD to EUR                 |
# | 2020-11-25        | 0.1     | Ramesh Sannareddy | Created initial version of the lab              |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
